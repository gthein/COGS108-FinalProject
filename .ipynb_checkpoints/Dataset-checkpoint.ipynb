# %%
import pandas as pd
import numpy as np

# %%
demographics = pd.read_sas('data/DEMO_I.XPT')
demographics.head()
# Out:
#       SEQN  SDDSRVYR  RIDSTATR  RIAGENDR  RIDAGEYR  RIDAGEMN  RIDRETH1  \
# 0  83732.0       9.0       2.0       1.0      62.0       NaN       3.0
# 1  83733.0       9.0       2.0       1.0      53.0       NaN       3.0
# 2  83734.0       9.0       2.0       1.0      78.0       NaN       3.0
# 3  83735.0       9.0       2.0       2.0      56.0       NaN       3.0
# 4  83736.0       9.0       2.0       2.0      42.0       NaN       4.0
#
#    RIDRETH3  RIDEXMON  RIDEXAGM  ...  DMDHREDU  DMDHRMAR  DMDHSEDU  \
# 0       3.0       1.0       NaN  ...       5.0       1.0       3.0
# 1       3.0       1.0       NaN  ...       3.0       3.0       NaN
# 2       3.0       2.0       NaN  ...       3.0       1.0       3.0
# 3       3.0       2.0       NaN  ...       5.0       6.0       NaN
# 4       4.0       2.0       NaN  ...       4.0       3.0       NaN
#
#         WTINT2YR       WTMEC2YR  SDMVPSU  SDMVSTRA  INDHHIN2  INDFMIN2  \
# 0  134671.370419  135629.507405      1.0     125.0      10.0      10.0
# 1   24328.560239   25282.425927      1.0     125.0       4.0       4.0
# 2   12400.008522   12575.838818      1.0     131.0       5.0       5.0
# 3  102717.995647  102078.634508      1.0     131.0      10.0      10.0
# 4   17627.674984   18234.736219      2.0     126.0       7.0       7.0
#
#    INDFMPIR
# 0      4.39
# 1      1.32
# 2      1.51
# 3      5.00
# 4      1.23
#
# [5 rows x 47 columns]

# %%
questionaire = pd.read_sas('data/DUQ_I.XPT')
questionaire.head()
# Out:
#       SEQN  DUQ200  DUQ210  DUQ211  DUQ213       DUQ215Q  DUQ215U  DUQ217  \
# 0  83732.0     NaN     NaN     NaN     NaN           NaN      NaN     NaN
# 1  83733.0     2.0     NaN     NaN     NaN           NaN      NaN     NaN
# 2  83735.0     2.0     NaN     NaN     NaN           NaN      NaN     NaN
# 3  83736.0     1.0    25.0     1.0    25.0  5.397605e-79      1.0     5.0
# 4  83741.0     1.0    15.0     1.0    16.0  1.000000e+00      4.0     4.0
#
#    DUQ219  DUQ220Q  ...  DUQ380B  DUQ380C  DUQ380D  DUQ380E  DUQ390  DUQ400Q  \
# 0     NaN      NaN  ...      NaN      NaN      NaN      NaN     NaN      NaN
# 1     NaN      NaN  ...      NaN      NaN      NaN      NaN     NaN      NaN
# 2     NaN      NaN  ...      NaN      NaN      NaN      NaN     NaN      NaN
# 3     4.0      1.0  ...      NaN      NaN      NaN      NaN     NaN      NaN
# 4     2.0      1.0  ...      NaN      NaN      NaN      NaN     NaN      NaN
#
#    DUQ400U  DUQ410  DUQ420  DUQ430
# 0      NaN     NaN     NaN     NaN
# 1      NaN     NaN     NaN     NaN
# 2      NaN     NaN     NaN     NaN
# 3      NaN     NaN     NaN     2.0
# 4      NaN     NaN     NaN     1.0
#
# [5 rows x 42 columns]

# %%
merged = pd.merge(demographics, questionaire, on = 'SEQN')
merged.head()
# Out:
#       SEQN  SDDSRVYR  RIDSTATR  RIAGENDR  RIDAGEYR  RIDAGEMN  RIDRETH1  \
# 0  83732.0       9.0       2.0       1.0      62.0       NaN       3.0
# 1  83733.0       9.0       2.0       1.0      53.0       NaN       3.0
# 2  83735.0       9.0       2.0       2.0      56.0       NaN       3.0
# 3  83736.0       9.0       2.0       2.0      42.0       NaN       4.0
# 4  83741.0       9.0       2.0       1.0      22.0       NaN       4.0
#
#    RIDRETH3  RIDEXMON  RIDEXAGM  ...  DUQ380B  DUQ380C  DUQ380D  DUQ380E  \
# 0       3.0       1.0       NaN  ...      NaN      NaN      NaN      NaN
# 1       3.0       1.0       NaN  ...      NaN      NaN      NaN      NaN
# 2       3.0       2.0       NaN  ...      NaN      NaN      NaN      NaN
# 3       4.0       2.0       NaN  ...      NaN      NaN      NaN      NaN
# 4       4.0       1.0       NaN  ...      NaN      NaN      NaN      NaN
#
#    DUQ390  DUQ400Q  DUQ400U  DUQ410  DUQ420  DUQ430
# 0     NaN      NaN      NaN     NaN     NaN     NaN
# 1     NaN      NaN      NaN     NaN     NaN     NaN
# 2     NaN      NaN      NaN     NaN     NaN     NaN
# 3     NaN      NaN      NaN     NaN     NaN     2.0
# 4     NaN      NaN      NaN     NaN     NaN     1.0
#
# [5 rows x 88 columns]

# %%
cols = ['SEQN', 'RIAGENDR', 'RIDAGEYR', 'DMDEDUC3', 'DMDEDUC2', 'DMDMARTL', 'RIDEXPRG', 'DMDFMSIZ', 'INDHHIN2', 
        'INDFMPIR', 'DMDHHSIZ', 'DMDHHSZA', 'DMDHHSZB', 'DMDHHSZE', 'DUQ200', 'DUQ210', 'DUQ217', 'DUQ211', 'DUQ213', 'DUQ215Q', 
        'DUQ219', 'DUQ220Q', 'DUQ230']
df = merged[cols]
df['CHILDREN_NUM'] = df['DMDHHSZA'] + df['DMDHHSZB']
df['EDUCATION'] = df['DMDEDUC2'].astype(str) + df['DMDEDUC3'].astype(str)
df['EDUCATION'] = df['EDUCATION'].str.strip('nan')
df['EDUCATION'] = df['EDUCATION'].astype(int)
df = df.drop(columns = ['DMDEDUC3', 'DMDEDUC2', 'DMDHHSZA', 'DMDHHSZB'])
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import sys
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-28-05774562adc4> in <module>()
#       6 df['EDUCATION'] = df['DMDEDUC2'].astype(str) + df['DMDEDUC3'].astype(str)
#       7 df['EDUCATION'] = df['EDUCATION'].str.strip('nan')
# ----> 8 df['EDUCATION'] = df['EDUCATION'].astype(int)
#       9 df = df.drop(columns = ['DMDEDUC3', 'DMDEDUC2', 'DMDHHSZA', 'DMDHHSZB'])
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/generic.py in astype(self, dtype, copy, errors, **kwargs)
#    5689             # else, only a single dtype is given
#    5690             new_data = self._data.astype(dtype=dtype, copy=copy, errors=errors,
# -> 5691                                          **kwargs)
#    5692             return self._constructor(new_data).__finalize__(self)
#    5693
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/internals/managers.py in astype(self, dtype, **kwargs)
#     529
#     530     def astype(self, dtype, **kwargs):
# --> 531         return self.apply('astype', dtype=dtype, **kwargs)
#     532
#     533     def convert(self, **kwargs):
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/internals/managers.py in apply(self, f, axes, filter, do_integrity_check, consolidate, **kwargs)
#     393                                             copy=align_copy)
#     394
# --> 395             applied = getattr(b, f)(**kwargs)
#     396             result_blocks = _extend_blocks(applied, result_blocks)
#     397
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/internals/blocks.py in astype(self, dtype, copy, errors, values, **kwargs)
#     532     def astype(self, dtype, copy=False, errors='raise', values=None, **kwargs):
#     533         return self._astype(dtype, copy=copy, errors=errors, values=values,
# --> 534                             **kwargs)
#     535
#     536     def _astype(self, dtype, copy=False, errors='raise', values=None,
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/internals/blocks.py in _astype(self, dtype, copy, errors, values, **kwargs)
#     631
#     632                     # _astype_nansafe works fine with 1-d only
# --> 633                     values = astype_nansafe(values.ravel(), dtype, copy=True)
#     634
#     635                 # TODO(extension)
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/dtypes/cast.py in astype_nansafe(arr, dtype, copy, skipna)
#     681         # work around NumPy brokenness, #1987
#     682         if np.issubdtype(dtype.type, np.integer):
# --> 683             return lib.astype_intsafe(arr.ravel(), dtype).reshape(arr.shape)
#     684
#     685         # if we have a datetime/timedelta array of objects
#
# pandas/_libs/lib.pyx in pandas._libs.lib.astype_intsafe()
#
# ValueError: invalid literal for int() with base 10: '5.0'

# %%
translation_dict = {'SEQN': 'ID', 'RIAGENDR': 'GENDER', 'RIDAGEYR': 'AGE', 'DMDMARTL': 'MARRIAGE', 
                    'RIDEXPRG': 'PREGNANCY', 'INDHHIN2': 'INCOME', 'INDFMPIR': 'INCOME_RATIO', 
                    'DMDHHSIZ': 'HOUSEHOLD_NUM', 'DMDHHSZE': 'OVER_60_NUM', 'DUQ200': 'EVER_USE', 
                    'DUQ210': 'FIRST_USAGE', 'DUQ217': 'FREQUENCY', 'DUQ211': 'PER_MONTH', 
                    'DUQ213': 'PER_YEAR', 'DUQ215Q': 'LAST_ONCE_MONTH', 'DUQ219': 'AMOUNT', 'DUQ220Q': 'LAST_USAGE', 
                    'DUQ230': 'PAST_MONTH_USAGE'}
df = df.rename(index = str, columns = translation_dict)
df[df['EDUCATION'].isnull() == False]
# Out:
#            ID  GENDER   AGE  DMDEDUC3  DMDEDUC2  MARRIAGE  PREGNANCY  \
# 0     83732.0     1.0  62.0       NaN       5.0       1.0        NaN
# 1     83733.0     1.0  53.0       NaN       3.0       3.0        NaN
# 2     83735.0     2.0  56.0       NaN       5.0       6.0        NaN
# 3     83736.0     2.0  42.0       NaN       4.0       3.0        1.0
# 4     83741.0     1.0  22.0       NaN       4.0       5.0        NaN
# 5     83742.0     2.0  32.0       NaN       4.0       1.0        2.0
# 6     83743.0     1.0  18.0      11.0       NaN       NaN        NaN
# 7     83744.0     1.0  56.0       NaN       3.0       3.0        NaN
# 8     83747.0     1.0  46.0       NaN       5.0       6.0        NaN
# 9     83750.0     1.0  45.0       NaN       2.0       5.0        NaN
# 10    83752.0     2.0  30.0       NaN       4.0       6.0        2.0
# 11    83754.0     2.0  67.0       NaN       5.0       1.0        NaN
# 12    83755.0     1.0  67.0       NaN       5.0       2.0        NaN
# 13    83757.0     2.0  57.0       NaN       1.0       4.0        NaN
# 14    83759.0     2.0  19.0      15.0       NaN       NaN        NaN
# 15    83761.0     2.0  24.0       NaN       5.0       5.0        2.0
# 16    83762.0     2.0  27.0       NaN       4.0       5.0        2.0
# 17    83767.0     2.0  54.0       NaN       4.0       3.0        NaN
# 18    83769.0     1.0  49.0       NaN       2.0       1.0        NaN
# 19    83775.0     2.0  69.0       NaN       1.0       4.0        NaN
# 20    83776.0     2.0  58.0       NaN       5.0       1.0        NaN
# 21    83777.0     1.0  56.0       NaN       2.0       1.0        NaN
# 22    83781.0     2.0  27.0       NaN       5.0       5.0        2.0
# 23    83784.0     1.0  22.0       NaN       4.0       5.0        NaN
# 24    83785.0     2.0  60.0       NaN       5.0       3.0        NaN
# 25    83786.0     1.0  51.0       NaN       4.0       5.0        NaN
# 26    83787.0     2.0  68.0       NaN       1.0       3.0        NaN
# 27    83788.0     2.0  69.0       NaN       4.0       1.0        NaN
# 28    83789.0     1.0  66.0       NaN       5.0       6.0        NaN
# 29    83790.0     1.0  56.0       NaN       1.0       1.0        NaN
# ...       ...     ...   ...       ...       ...       ...        ...
# 4813  93629.0     2.0  51.0       NaN       1.0       3.0        NaN
# 4814  93631.0     2.0  68.0       NaN       4.0       1.0        NaN
# 4815  93633.0     1.0  63.0       NaN       3.0       5.0        NaN
# 4816  93638.0     1.0  33.0       NaN       2.0       1.0        NaN
# 4817  93639.0     1.0  25.0       NaN       5.0       6.0        NaN
# 4818  93640.0     1.0  38.0       NaN       4.0       1.0        NaN
# 4819  93643.0     2.0  64.0       NaN       3.0       1.0        NaN
# 4820  93653.0     2.0  25.0       NaN       5.0       6.0        2.0
# 4821  93654.0     2.0  29.0       NaN       5.0       1.0        2.0
# 4822  93655.0     1.0  38.0       NaN       2.0       3.0        NaN
# 4823  93659.0     1.0  62.0       NaN       1.0       1.0        NaN
# 4824  93661.0     2.0  27.0       NaN       4.0       6.0        2.0
# 4825  93663.0     1.0  43.0       NaN       1.0       1.0        NaN
# 4826  93664.0     1.0  39.0       NaN       3.0       1.0        NaN
# 4827  93665.0     2.0  34.0       NaN       5.0       1.0        2.0
# 4828  93670.0     1.0  32.0       NaN       5.0       1.0        NaN
# 4829  93671.0     1.0  45.0       NaN       5.0       1.0        NaN
# 4830  93672.0     2.0  63.0       NaN       1.0       1.0        NaN
# 4831  93675.0     1.0  38.0       NaN       5.0       4.0        NaN
# 4832  93676.0     2.0  35.0       NaN       5.0       3.0        3.0
# 4833  93677.0     2.0  34.0       NaN       5.0       5.0        2.0
# 4834  93682.0     2.0  41.0       NaN       5.0       1.0        2.0
# 4835  93684.0     1.0  34.0       NaN       5.0       1.0        NaN
# 4836  93685.0     1.0  53.0       NaN       2.0       1.0        NaN
# 4837  93689.0     2.0  69.0       NaN       1.0       1.0        NaN
# 4838  93690.0     1.0  32.0       NaN       2.0       1.0        NaN
# 4839  93691.0     1.0  25.0       NaN       5.0       5.0        NaN
# 4840  93696.0     1.0  26.0       NaN       5.0       1.0        NaN
# 4841  93700.0     1.0  35.0       NaN       1.0       1.0        NaN
# 4842  93702.0     2.0  24.0       NaN       5.0       5.0        2.0
#
#       DMDFMSIZ  INCOME  INCOME_RATIO  ...  FIRST_USAGE  FREQUENCY  PER_MONTH  \
# 0          2.0    10.0  4.390000e+00  ...          NaN        NaN        NaN
# 1          1.0     4.0  1.320000e+00  ...          NaN        NaN        NaN
# 2          1.0    10.0  5.000000e+00  ...          NaN        NaN        NaN
# 3          5.0     7.0  1.230000e+00  ...         25.0        5.0        1.0
# 4          3.0     7.0  2.080000e+00  ...         15.0        4.0        1.0
# 5          4.0     6.0  1.030000e+00  ...         18.0        NaN        2.0
# 6          3.0    15.0  5.000000e+00  ...          NaN        NaN        NaN
# 7          1.0     3.0  1.190000e+00  ...         18.0        NaN        2.0
# 8          2.0     3.0  7.500000e-01  ...          NaN        NaN        NaN
# 9          1.0    10.0  1.360000e+00  ...         21.0        NaN        2.0
# 10         2.0    15.0  5.000000e+00  ...         14.0        NaN        2.0
# 11         7.0     6.0  8.900000e-01  ...          NaN        NaN        NaN
# 12         1.0     5.0  2.040000e+00  ...          NaN        NaN        NaN
# 13         5.0     5.0  7.700000e-01  ...          NaN        NaN        NaN
# 14         3.0     7.0  1.740000e+00  ...          NaN        NaN        NaN
# 15         1.0     1.0  5.397605e-79  ...          NaN        NaN        NaN
# 16         1.0     8.0  2.120000e+00  ...          NaN        NaN        NaN
# 17         6.0    14.0  2.990000e+00  ...          NaN        NaN        NaN
# 18         4.0    10.0  2.970000e+00  ...          NaN        NaN        NaN
# 19         1.0     2.0  5.500000e-01  ...          NaN        NaN        NaN
# 20         3.0    14.0  3.720000e+00  ...          NaN        NaN        NaN
# 21         5.0     7.0  1.350000e+00  ...          NaN        NaN        NaN
# 22         2.0    77.0           NaN  ...         20.0        3.0        1.0
# 23         4.0     NaN           NaN  ...         12.0        5.0        1.0
# 24         4.0    15.0  5.000000e+00  ...          NaN        NaN        NaN
# 25         1.0    77.0           NaN  ...          NaN        NaN        NaN
# 26         1.0     4.0  1.490000e+00  ...          NaN        NaN        NaN
# 27         3.0     7.0  1.790000e+00  ...          NaN        NaN        NaN
# 28         1.0    10.0  5.000000e+00  ...          NaN        NaN        NaN
# 29         2.0     4.0  1.000000e+00  ...         15.0        NaN        2.0
# ...        ...     ...           ...  ...          ...        ...        ...
# 4813       1.0     3.0  1.010000e+00  ...          NaN        NaN        NaN
# 4814       2.0     6.0  2.030000e+00  ...          NaN        NaN        NaN
# 4815       2.0     5.0  1.250000e+00  ...          NaN        NaN        NaN
# 4816       5.0    77.0           NaN  ...          NaN        NaN        NaN
# 4817       1.0    14.0  4.250000e+00  ...         17.0        4.0        1.0
# 4818       4.0     9.0  2.470000e+00  ...          NaN        NaN        NaN
# 4819       1.0     2.0  2.000000e-01  ...          NaN        NaN        NaN
# 4820       1.0    14.0  2.970000e+00  ...         19.0        2.0        1.0
# 4821       2.0    99.0           NaN  ...          NaN        NaN        NaN
# 4822       4.0     6.0  1.150000e+00  ...         15.0        4.0        1.0
# 4823       7.0    15.0  3.270000e+00  ...          NaN        NaN        NaN
# 4824       4.0     4.0  7.400000e-01  ...         18.0        NaN        2.0
# 4825       6.0     7.0  1.070000e+00  ...          NaN        NaN        NaN
# 4826       5.0    15.0  4.930000e+00  ...          NaN        NaN        NaN
# 4827       4.0    15.0  4.120000e+00  ...          NaN        NaN        NaN
# 4828       4.0    12.0           NaN  ...         16.0        5.0        1.0
# 4829       3.0    15.0  5.000000e+00  ...          NaN        NaN        NaN
# 4830       3.0     1.0  2.000000e-01  ...          NaN        NaN        NaN
# 4831       1.0    15.0  5.000000e+00  ...          NaN        NaN        NaN
# 4832       2.0     7.0  2.680000e+00  ...          NaN        NaN        NaN
# 4833       1.0    12.0  1.760000e+00  ...         22.0        NaN        2.0
# 4834       5.0    15.0  5.000000e+00  ...          NaN        NaN        NaN
# 4835       5.0    14.0  2.810000e+00  ...          NaN        NaN        NaN
# 4836       5.0     3.0  4.900000e-01  ...         18.0        NaN        2.0
# 4837       1.0     3.0  9.700000e-01  ...          NaN        NaN        NaN
# 4838       4.0    15.0  5.000000e+00  ...         13.0        5.0        1.0
# 4839       7.0    10.0  1.590000e+00  ...          NaN        NaN        NaN
# 4840       3.0     9.0  2.990000e+00  ...          NaN        NaN        NaN
# 4841       5.0     1.0  5.397605e-79  ...          NaN        NaN        NaN
# 4842       1.0    10.0  3.540000e+00  ...         16.0        NaN        2.0
#
#       PER_YEAR  LAST_ONCE_MONTH  AMOUNT  LAST_USAGE  PAST_MONTH_USAGE  \
# 0          NaN              NaN     NaN         NaN               NaN
# 1          NaN              NaN     NaN         NaN               NaN
# 2          NaN              NaN     NaN         NaN               NaN
# 3         25.0     5.397605e-79     4.0         1.0              30.0
# 4         16.0     1.000000e+00     2.0         1.0              25.0
# 5          NaN              NaN     NaN        13.0               NaN
# 6          NaN              NaN     NaN         NaN               NaN
# 7          NaN              NaN     NaN        20.0               NaN
# 8          NaN              NaN     NaN         NaN               NaN
# 9          NaN              NaN     NaN        20.0               1.0
# 10         NaN              NaN     NaN        13.0               NaN
# 11         NaN              NaN     NaN         NaN               NaN
# 12         NaN              NaN     NaN         NaN               NaN
# 13         NaN              NaN     NaN         NaN               NaN
# 14         NaN              NaN     NaN         NaN               NaN
# 15         NaN              NaN     NaN         NaN               NaN
# 16         NaN              NaN     NaN         NaN               NaN
# 17         NaN              NaN     NaN         NaN               NaN
# 18         NaN              NaN     NaN         NaN               NaN
# 19         NaN              NaN     NaN         NaN               NaN
# 20         NaN              NaN     NaN         NaN               NaN
# 21         NaN              NaN     NaN         NaN               NaN
# 22        20.0     4.000000e+00     1.0         4.0               NaN
# 23        13.0     5.397605e-79     4.0         1.0              27.0
# 24         NaN              NaN     NaN         NaN               NaN
# 25         NaN              NaN     NaN         NaN               NaN
# 26         NaN              NaN     NaN         NaN               NaN
# 27         NaN              NaN     NaN         NaN               NaN
# 28         NaN              NaN     NaN         NaN               NaN
# 29         NaN              NaN     NaN        24.0               NaN
# ...        ...              ...     ...         ...               ...
# 4813       NaN              NaN     NaN         NaN               NaN
# 4814       NaN              NaN     NaN         NaN               NaN
# 4815       NaN              NaN     NaN         NaN               NaN
# 4816       NaN              NaN     NaN         NaN               NaN
# 4817      18.0     7.000000e+00     1.0         3.0               NaN
# 4818       NaN              NaN     NaN         NaN               NaN
# 4819       NaN              NaN     NaN         NaN               NaN
# 4820      19.0     4.000000e+00     1.0         4.0               NaN
# 4821       NaN              NaN     NaN         NaN               NaN
# 4822      15.0     2.000000e+00     1.0         2.0              14.0
# 4823       NaN              NaN     NaN         NaN               NaN
# 4824       NaN              NaN     NaN         9.0               NaN
# 4825       NaN              NaN     NaN         NaN               NaN
# 4826       NaN              NaN     NaN         NaN               NaN
# 4827       NaN              NaN     NaN         NaN               NaN
# 4828      16.0     1.000000e+01     3.0         4.0               NaN
# 4829       NaN              NaN     NaN         NaN               NaN
# 4830       NaN              NaN     NaN         NaN               NaN
# 4831       NaN              NaN     NaN         NaN               NaN
# 4832       NaN              NaN     NaN         NaN               NaN
# 4833       NaN              NaN     NaN         5.0               NaN
# 4834       NaN              NaN     NaN         NaN               NaN
# 4835       NaN              NaN     NaN         NaN               NaN
# 4836       NaN              NaN     NaN      9999.0               NaN
# 4837       NaN              NaN     NaN         NaN               NaN
# 4838      17.0     8.000000e+00     3.0         8.0               NaN
# 4839       NaN              NaN     NaN         NaN               NaN
# 4840       NaN              NaN     NaN         NaN               NaN
# 4841       NaN              NaN     NaN         NaN               NaN
# 4842       NaN              NaN     NaN         2.0               NaN
#
#       CHILDREN_NUM  EDUCATION
# 0     1.079521e-78        5.0
# 1     1.079521e-78        3.0
# 2     1.079521e-78        5.0
# 3     2.000000e+00        4.0
# 4     1.079521e-78        4.0
# 5     2.000000e+00        4.0
# 6     1.079521e-78       11.0
# 7     1.079521e-78        3.0
# 8     1.079521e-78        5.0
# 9     2.000000e+00        2.0
# 10    1.079521e-78        4.0
# 11    3.000000e+00        5.0
# 12    1.079521e-78        5.0
# 13    1.000000e+00        1.0
# 14    1.079521e-78       15.0
# 15    1.079521e-78        5.0
# 16    1.079521e-78        4.0
# 17    2.000000e+00        4.0
# 18    1.000000e+00        2.0
# 19    1.079521e-78        1.0
# 20    1.000000e+00        5.0
# 21    1.079521e-78        2.0
# 22    1.079521e-78        5.0
# 23    1.079521e-78        4.0
# 24    1.079521e-78        5.0
# 25    1.079521e-78        4.0
# 26    1.079521e-78        1.0
# 27    1.000000e+00        4.0
# 28    1.079521e-78        5.0
# 29    1.079521e-78        1.0
# ...            ...        ...
# 4813  1.079521e-78        1.0
# 4814  1.079521e-78        4.0
# 4815  1.079521e-78        3.0
# 4816  3.000000e+00        2.0
# 4817  1.079521e-78        5.0
# 4818  2.000000e+00        4.0
# 4819  1.079521e-78        3.0
# 4820  1.079521e-78        5.0
# 4821  1.079521e-78        5.0
# 4822  2.000000e+00        2.0
# 4823  3.000000e+00        1.0
# 4824  2.000000e+00        4.0
# 4825  4.000000e+00        1.0
# 4826  2.000000e+00        3.0
# 4827  2.000000e+00        5.0
# 4828  1.079521e-78        5.0
# 4829  1.000000e+00        5.0
# 4830  1.079521e-78        1.0
# 4831  1.079521e-78        5.0
# 4832  1.000000e+00        5.0
# 4833  1.079521e-78        5.0
# 4834  2.000000e+00        5.0
# 4835  3.000000e+00        5.0
# 4836  2.000000e+00        2.0
# 4837  1.079521e-78        1.0
# 4838  1.000000e+00        2.0
# 4839  2.000000e+00        5.0
# 4840  1.000000e+00        5.0
# 4841  3.000000e+00        1.0
# 4842  1.079521e-78        5.0
#
# [4843 rows x 25 columns]
